# %%
import numpy as np

from ch_util import andata
from chimedb import core, dataset as ds

# %% [markdown]
# Connect to the database and load a file (but only the dataset listing the dataset_ids contained in it)

# %%
core.connect()

# %%
fname = "/project/rpp-chime/chime/chime_online/20220901T034310Z_chimestack_corr/00000000_0000.h5"
ad = andata.CorrData.from_acq_h5(fname, datasets=("flags/dataset_id",))

# %% [markdown]
# Print out some of the dataset IDs in the file. As the first frequency is usually missing the dataset_ids associated with it are all the null state (32 zeros).

# %%
ad.flags["dataset_id"][:2, :5]
# Out:
# array([['00000000000000000000000000000000',
#         '00000000000000000000000000000000',
#         '00000000000000000000000000000000',
#         '00000000000000000000000000000000',
#         '00000000000000000000000000000000'],
#        ['f938c2a20aa96de5bcc062ebaadf72fd',
#         'f938c2a20aa96de5bcc062ebaadf72fd',
#         'f938c2a20aa96de5bcc062ebaadf72fd',
#         'f938c2a20aa96de5bcc062ebaadf72fd',
#         'f938c2a20aa96de5bcc062ebaadf72fd']], dtype='<U33')

# %% [markdown]
# There's usually a lot of repeated states in a file, so you probably only want to bother processing the unique entries. Here we'll show how to do the queries directly, but the `chimedb.dataset.utils.state_id_of_type` routine is particularly useful for this type of analysis.

# %%
unique_dataset_ids = np.unique(ad.flags["dataset_id"][:])

# %% [markdown]
# We don't want to use the null dataset so we trim it off. As the output of `np.unique` is sorted we know that the null entry is the first. Also there's an issue with the string types numpy uses so we need to explicitly turn them into Python strings.

# %%
unique_dataset_ids = [str(u) for u in unique_dataset_ids[1:]]

# %% [markdown]
# The datasets form a chain listing all the transformations done to the data through the realtime system. Let's try and get the list of all transformations for one of the IDs. This is (going from the most recent, to the earliest transformation)...

# %%
dt = ds.Dataset.from_id(unique_dataset_ids[0])

while True:
    print(f"dataset_id={dt.id}; state_id={dt.state.id}; state_type={dt.state.type.name}")
    
    if dt.root:
        break
        
    dt = dt.base_dataset
# Out:
# dataset_id=05ed10f854fca62d40d6b5989c2dad7d; state_id=4dbfcd1acd2d3f7781f60144dd6b5667; state_type=eigenvalues
# dataset_id=83b12f20b7e6b5c8fd4466f606de13b7; state_id=b4240cad7a2244de961a3ca3a848cf1a; state_type=stack
# dataset_id=094f859a94ba19fc2034d7e07d5d8455; state_id=161c8277d3d08e97faeb0f41d2a974bb; state_type=gains
# dataset_id=2245b69af56d0f35eb4fd46aa5dbcbc1; state_id=3d65f6cc04c941ad59beccbba7c5a49c; state_type=flags
# dataset_id=b35fd161e72250e4801f3028deff5b54; state_id=178bd8e562838eb9b9b38549789fa42e; state_type=eigenvalues
# dataset_id=2931ab110bfe32430a155c7837e72e0f; state_id=f57a844248d29dc0a1954e9b91e261c7; state_type=gating
# dataset_id=a51129fd92c6d980d99754c77d430d5e; state_id=5e2a864b31621d630b313d6d2d299631; state_type=metadata
# dataset_id=1396459024c927a5e4dfcbe13ae09d5f; state_id=4dbfcd1acd2d3f7781f60144dd6b5667; state_type=eigenvalues
# dataset_id=592e01f52865a9a79fdb5481e631e88b; state_id=60db9f8d3e315e30b4893a1cf7ee3645; state_type=products
# dataset_id=ed6878dee99abf744bc03174e08edd2e; state_id=249e1645cbad7274c89b30f489a520c5; state_type=inputs
# dataset_id=01700c076c7d1bc7e602e7ff20e39792; state_id=fbbf0fe9687b7428880092d0f78474cf; state_type=frequencies
# dataset_id=41a28c1cbd5a1b664741580658dacf8c; state_id=77e35ae41d08c8125bee11bba1bfe43b; state_type=rfi_frame_drop
# dataset_id=afa03080c5e234525702cb7da98beac6; state_id=7214cc53dfdd6b74d46318ed85786bd9; state_type=f_engine_frequency_map
# dataset_id=c085f9da34a269da8b202684dc44b261; state_id=88025bddf14f34c3b430798d5c0af9a0; state_type=f_engine_hardware
# dataset_id=a3c7ea4888a4934cfdfafdc184edffc6; state_id=f0cd43cb50246f01a609a007a4d54827; state_type=start_pychfpga.fpga_master
# dataset_id=9bcdd07162678dd4cf1982c17b6a1b18; state_id=6fd4caef8bfef32e1a4d258f8ea3cb9a; state_type=config_pychfpga.fpga_master

# %% [markdown]
# Each of these state entries contains metadata describing exactly what the change of state was. Let's have a look at the changes to the eigenvalue state over time.

# %%
dt = ds.Dataset.from_id(unique_dataset_ids[0])

while True:
    
    if dt.state.type.name == "eigenvalues":
        print(f"dataset_id={dt.id}; state_data={dt.state.data}")
    
    if dt.root:
        break
        
    dt = dt.base_dataset
# Out:
# dataset_id=05ed10f854fca62d40d6b5989c2dad7d; state_data={'data': [], 'type': 'eigenvalues'}
# dataset_id=b35fd161e72250e4801f3028deff5b54; state_data={'data': [0, 1, 2, 3], 'type': 'eigenvalues'}
# dataset_id=1396459024c927a5e4dfcbe13ae09d5f; state_data={'data': [], 'type': 'eigenvalues'}

# %% [markdown]
# We can read this as saying that (from bottom to top) the system started with zero eigenvalues saved into the data, that at a later stage the first four eigenvalues were calculated and added into the data, and then at an even later stage, the eigenvalues were removed (empty list).

# %% [markdown]
# Let's try and find all the frequency maps used in this file. We do that by fetching the full dataset object for each ID and then looking for the most recent `"f_engine_frequency_map"` type in the chain of dataset IDs. We'll save a dictionary of the state IDs and the frequency map data. This is sufficient as state IDs have a one-to-one mapping to the state type, and associated data.
#
# While we're at it, we'll also extract the F-engine config via the `config_pychfpga.fpga_master` type.

# %%
fmaps = {}
fconf = {}

for dsid in unique_dataset_ids:
    d = ds.Dataset.from_id(str(unique_dataset_ids[0]))
    
    ancestor = d.closest_ancestor_of_type("f_engine_frequency_map")
    state = ancestor.state
    fmaps[state.id] = state.data
    
    ancestor = d.closest_ancestor_of_type("config_pychfpga.fpga_master")
    state = ancestor.state
    fconf[state.id] = state.data

# %%
list(fmaps.keys()), list(fconf.keys()),
# Out:
# (['7214cc53dfdd6b74d46318ed85786bd9'], ['6fd4caef8bfef32e1a4d258f8ea3cb9a'])

# %% [markdown]
# Great, we found only one corresponding state. That is even though we found several different dataset_ids in the file they all share the same F-engine frequency map (as we would expect as the map isn't changed very often).
#
# Let's look at some of the data, in this case the first 10 entries in the map

# %%
first_10_maps = {stream_id: freq_id_map for ii, (stream_id, freq_id_map) in enumerate(list(fmaps.values())[0]["fmap"].items()) if ii < 10}
first_10_maps
# Out:
# {'12288': [185, 265, 281, 289],
#  '12289': [193, 305, 329, 761],
#  '12290': [121, 129, 137, 169],
#  '12291': [313, 321, 361, 417],
#  '12292': [201, 337, 425, 489],
#  '12293': [81, 393, 401, 409],
#  '12294': [113, 145, 153, 177],
#  '12295': [1, 369, 473, 481],
#  '12304': [524, 620, 692, 732],
#  '12305': [100, 540, 612, 924]}

# %% [markdown]
# Juan assures me that the string keys correspond to the stream IDs and that they can be decoded like this

# %%
# stream_id = shuffle*2**12 + crate*2**8 + slot*2**4 + link
def decode_stream_id(stream_id: str) -> tuple[int]:
    
    stream_id = int(stream_id)
    
    link = stream_id & 15
    slot = (stream_id >> 4) & 15
    crate = (stream_id >> 8) & 15
    shuffle = (stream_id >> 12) & 15
    
    return (shuffle, crate, slot, link)

# %%
for stream_id, freq_id_map in first_10_maps.items():
    print(decode_stream_id(stream_id), freq_id_map)
# Out:
# (3, 0, 0, 0) [185, 265, 281, 289]
# (3, 0, 0, 1) [193, 305, 329, 761]
# (3, 0, 0, 2) [121, 129, 137, 169]
# (3, 0, 0, 3) [313, 321, 361, 417]
# (3, 0, 0, 4) [201, 337, 425, 489]
# (3, 0, 0, 5) [81, 393, 401, 409]
# (3, 0, 0, 6) [113, 145, 153, 177]
# (3, 0, 0, 7) [1, 369, 473, 481]
# (3, 0, 1, 0) [524, 620, 692, 732]
# (3, 0, 1, 1) [100, 540, 612, 924]

# %% [markdown]
# For interest here is the serialised F-engine config obtained via the dataset states

# %%
list(fconf.values())[0]
# Out:
# {'input_reorder': [[128, 0, 'FCC000812'],
#   [129, 1, 'FCC000813'],
#   [130, 2, 'FCC000814'],
#   [131, 3, 'FCC000815'],
#   [132, 4, 'FCC000808'],
#   [133, 5, 'FCC000809'],
#   [134, 6, 'FCC000810'],
#   [135, 7, 'FCC000811'],
#   [136, 8, 'FCC000804'],
#   [137, 9, 'FCC000805'],
#   [138, 10, 'FCC000806'],
#   [139, 11, 'FCC000807'],
#   [140, 12, 'FCC000800'],
#   [141, 13, 'FCC000801'],
#   [142, 14, 'FCC000802'],
#   [143, 15, 'FCC000803'],
#   [160, 16, 'FCC001012'],
#   [161, 17, 'FCC001013'],
#   [162, 18, 'FCC001014'],
#   [163, 19, 'FCC001015'],
#   [164, 20, 'FCC001008'],
#   [165, 21, 'FCC001009'],
#   [166, 22, 'FCC001010'],
#   [167, 23, 'FCC001011'],
#   [168, 24, 'FCC001004'],
#   [169, 25, 'FCC001005'],
#   [170, 26, 'FCC001006'],
#   [171, 27, 'FCC001007'],
#   [172, 28, 'FCC001000'],
#   [173, 29, 'FCC001001'],
#   [174, 30, 'FCC001002'],
#   [175, 31, 'FCC001003'],
#   [192, 32, 'FCC001212'],
#   [193, 33, 'FCC001213'],
#   [194, 34, 'FCC001214'],
#   [195, 35, 'FCC001215'],
#   [196, 36, 'FCC001208'],
#   [197, 37, 'FCC001209'],
#   [198, 38, 'FCC001210'],
#   [199, 39, 'FCC001211'],
#   [200, 40, 'FCC001204'],
#   [201, 41, 'FCC001205'],
#   [202, 42, 'FCC001206'],
#   [203, 43, 'FCC001207'],
#   [204, 44, 'FCC001200'],
#   [205, 45, 'FCC001201'],
#   [206, 46, 'FCC001202'],
#   [207, 47, 'FCC001203'],
#   [224, 48, 'FCC001412'],
#   [225, 49, 'FCC001413'],
#   [226, 50, 'FCC001414'],
#   [227, 51, 'FCC001415'],
#   [228, 52, 'FCC001408'],
#   [229, 53, 'FCC001409'],
#   [230, 54, 'FCC001410'],
#   [231, 55, 'FCC001411'],
#   [232, 56, 'FCC001404'],
#   [233, 57, 'FCC001405'],
#   [234, 58, 'FCC001406'],
#   [235, 59, 'FCC001407'],
#   [236, 60, 'FCC001400'],
#   [237, 61, 'FCC001401'],
#   [238, 62, 'FCC001402'],
#   [239, 63, 'FCC001403'],
#   [384, 64, 'FCC010812'],
#   [385, 65, 'FCC010813'],
#   [386, 66, 'FCC010814'],
#   [387, 67, 'FCC010815'],
#   [388, 68, 'FCC010808'],
#   [389, 69, 'FCC010809'],
#   [390, 70, 'FCC010810'],
#   [391, 71, 'FCC010811'],
#   [392, 72, 'FCC010804'],
#   [393, 73, 'FCC010805'],
#   [394, 74, 'FCC010806'],
#   [395, 75, 'FCC010807'],
#   [396, 76, 'FCC010800'],
#   [397, 77, 'FCC010801'],
#   [398, 78, 'FCC010802'],
#   [399, 79, 'FCC010803'],
#   [416, 80, 'FCC011012'],
#   [417, 81, 'FCC011013'],
#   [418, 82, 'FCC011014'],
#   [419, 83, 'FCC011015'],
#   [420, 84, 'FCC011008'],
#   [421, 85, 'FCC011009'],
#   [422, 86, 'FCC011010'],
#   [423, 87, 'FCC011011'],
#   [424, 88, 'FCC011004'],
#   [425, 89, 'FCC011005'],
#   [426, 90, 'FCC011006'],
#   [427, 91, 'FCC011007'],
#   [428, 92, 'FCC011000'],
#   [429, 93, 'FCC011001'],
#   [430, 94, 'FCC011002'],
#   [431, 95, 'FCC011003'],
#   [448, 96, 'FCC011212'],
#   [449, 97, 'FCC011213'],
#   [450, 98, 'FCC011214'],
#   [451, 99, 'FCC011215'],
#   [452, 100, 'FCC011208'],
#   [453, 101, 'FCC011209'],
#   [454, 102, 'FCC011210'],
#   [455, 103, 'FCC011211'],
#   [456, 104, 'FCC011204'],
#   [457, 105, 'FCC011205'],
#   [458, 106, 'FCC011206'],
#   [459, 107, 'FCC011207'],
#   [460, 108, 'FCC011200'],
#   [461, 109, 'FCC011201'],
#   [462, 110, 'FCC011202'],
#   [463, 111, 'FCC011203'],
#   [480, 112, 'FCC011412'],
#   [481, 113, 'FCC011413'],
#   [482, 114, 'FCC011414'],
#   [483, 115, 'FCC011415'],
#   [484, 116, 'FCC011408'],
#   [485, 117, 'FCC011409'],
#   [486, 118, 'FCC011410'],
#   [487, 119, 'FCC011411'],
#   [488, 120, 'FCC011404'],
#   [489, 121, 'FCC011405'],
#   [490, 122, 'FCC011406'],
#   [491, 123, 'FCC011407'],
#   [492, 124, 'FCC011400'],
#   [493, 125, 'FCC011401'],
#   [494, 126, 'FCC011402'],
#   [495, 127, 'FCC011403'],
#   [268, 128, 'FCC010000'],
#   [269, 129, 'FCC010001'],
#   [270, 130, 'FCC010002'],
#   [271, 131, 'FCC010003'],
#   [264, 132, 'FCC010004'],
#   [265, 133, 'FCC010005'],
#   [266, 134, 'FCC010006'],
#   [267, 135, 'FCC010007'],
#   [260, 136, 'FCC010008'],
#   [261, 137, 'FCC010009'],
#   [262, 138, 'FCC010010'],
#   [263, 139, 'FCC010011'],
#   [256, 140, 'FCC010012'],
#   [257, 141, 'FCC010013'],
#   [258, 142, 'FCC010014'],
#   [259, 143, 'FCC010015'],
#   [300, 144, 'FCC010200'],
#   [301, 145, 'FCC010201'],
#   [302, 146, 'FCC010202'],
#   [303, 147, 'FCC010203'],
#   [296, 148, 'FCC010204'],
#   [297, 149, 'FCC010205'],
#   [298, 150, 'FCC010206'],
#   [299, 151, 'FCC010207'],
#   [292, 152, 'FCC010208'],
#   [293, 153, 'FCC010209'],
#   [294, 154, 'FCC010210'],
#   [295, 155, 'FCC010211'],
#   [288, 156, 'FCC010212'],
#   [289, 157, 'FCC010213'],
#   [290, 158, 'FCC010214'],
#   [291, 159, 'FCC010215'],
#   [332, 160, 'FCC010400'],
#   [333, 161, 'FCC010401'],
#   [334, 162, 'FCC010402'],
#   [335, 163, 'FCC010403'],
#   [328, 164, 'FCC010404'],
#   [329, 165, 'FCC010405'],
#   [330, 166, 'FCC010406'],
#   [331, 167, 'FCC010407'],
#   [324, 168, 'FCC010408'],
#   [325, 169, 'FCC010409'],
#   [326, 170, 'FCC010410'],
#   [327, 171, 'FCC010411'],
#   [320, 172, 'FCC010412'],
#   [321, 173, 'FCC010413'],
#   [322, 174, 'FCC010414'],
#   [323, 175, 'FCC010415'],
#   [364, 176, 'FCC010600'],
#   [365, 177, 'FCC010601'],
#   [366, 178, 'FCC010602'],
#   [367, 179, 'FCC010603'],
#   [360, 180, 'FCC010604'],
#   [361, 181, 'FCC010605'],
#   [362, 182, 'FCC010606'],
#   [363, 183, 'FCC010607'],
#   [356, 184, 'FCC010608'],
#   [357, 185, 'FCC010609'],
#   [358, 186, 'FCC010610'],
#   [359, 187, 'FCC010611'],
#   [352, 188, 'FCC010612'],
#   [353, 189, 'FCC010613'],
#   [354, 190, 'FCC010614'],
#   [355, 191, 'FCC010615'],
#   [12, 192, 'FCC000000'],
#   [13, 193, 'FCC000001'],
#   [14, 194, 'FCC000002'],
#   [15, 195, 'FCC000003'],
#   [8, 196, 'FCC000004'],
#   [9, 197, 'FCC000005'],
#   [10, 198, 'FCC000006'],
#   [11, 199, 'FCC000007'],
#   [4, 200, 'FCC000008'],
#   [5, 201, 'FCC000009'],
#   [6, 202, 'FCC000010'],
#   [7, 203, 'FCC000011'],
#   [0, 204, 'FCC000012'],
#   [1, 205, 'FCC000013'],
#   [2, 206, 'FCC000014'],
#   [3, 207, 'FCC000015'],
#   [44, 208, 'FCC000200'],
#   [45, 209, 'FCC000201'],
#   [46, 210, 'FCC000202'],
#   [47, 211, 'FCC000203'],
#   [40, 212, 'FCC000204'],
#   [41, 213, 'FCC000205'],
#   [42, 214, 'FCC000206'],
#   [43, 215, 'FCC000207'],
#   [36, 216, 'FCC000208'],
#   [37, 217, 'FCC000209'],
#   [38, 218, 'FCC000210'],
#   [39, 219, 'FCC000211'],
#   [32, 220, 'FCC000212'],
#   [34, 221, 'FCC000214'],
#   [33, 222, 'FCC000213'],
#   [35, 223, 'FCC000215'],
#   [76, 224, 'FCC000400'],
#   [77, 225, 'FCC000401'],
#   [78, 226, 'FCC000402'],
#   [79, 227, 'FCC000403'],
#   [72, 228, 'FCC000404'],
#   [73, 229, 'FCC000405'],
#   [74, 230, 'FCC000406'],
#   [75, 231, 'FCC000407'],
#   [68, 232, 'FCC000408'],
#   [69, 233, 'FCC000409'],
#   [70, 234, 'FCC000410'],
#   [71, 235, 'FCC000411'],
#   [64, 236, 'FCC000412'],
#   [65, 237, 'FCC000413'],
#   [66, 238, 'FCC000414'],
#   [67, 239, 'FCC000415'],
#   [108, 240, 'FCC000600'],
#   [109, 241, 'FCC000601'],
#   [110, 242, 'FCC000602'],
#   [111, 243, 'FCC000603'],
#   [104, 244, 'FCC000604'],
#   [105, 245, 'FCC000605'],
#   [106, 246, 'FCC000606'],
#   [107, 247, 'FCC000607'],
#   [100, 248, 'FCC000608'],
#   [101, 249, 'FCC000609'],
#   [102, 250, 'FCC000610'],
#   [103, 251, 'FCC000611'],
#   [96, 252, 'FCC000612'],
#   [97, 253, 'FCC000613'],
#   [98, 254, 'FCC000614'],
#   [99, 255, 'FCC000615'],
#   [144, 256, 'FCC000912'],
#   [145, 257, 'FCC000913'],
#   [146, 258, 'FCC000914'],
#   [147, 259, 'FCC000915'],
#   [148, 260, 'FCC000908'],
#   [149, 261, 'FCC000909'],
#   [150, 262, 'FCC000910'],
#   [151, 263, 'FCC000911'],
#   [152, 264, 'FCC000904'],
#   [153, 265, 'FCC000905'],
#   [154, 266, 'FCC000906'],
#   [155, 267, 'FCC000907'],
#   [156, 268, 'FCC000900'],
#   [157, 269, 'FCC000901'],
#   [158, 270, 'FCC000902'],
#   [159, 271, 'FCC000903'],
#   [176, 272, 'FCC001112'],
#   [177, 273, 'FCC001113'],
#   [178, 274, 'FCC001114'],
#   [179, 275, 'FCC001115'],
#   [180, 276, 'FCC001108'],
#   [181, 277, 'FCC001109'],
#   [182, 278, 'FCC001110'],
#   [183, 279, 'FCC001111'],
#   [184, 280, 'FCC001104'],
#   [185, 281, 'FCC001105'],
#   [186, 282, 'FCC001106'],
#   [187, 283, 'FCC001107'],
#   [188, 284, 'FCC001100'],
#   [189, 285, 'FCC001101'],
#   [190, 286, 'FCC001102'],
#   [191, 287, 'FCC001103'],
#   [208, 288, 'FCC001312'],
#   [209, 289, 'FCC001313'],
#   [210, 290, 'FCC001314'],
#   [211, 291, 'FCC001315'],
#   [212, 292, 'FCC001308'],
#   [213, 293, 'FCC001309'],
#   [214, 294, 'FCC001310'],
#   [215, 295, 'FCC001311'],
#   [216, 296, 'FCC001304'],
#   [217, 297, 'FCC001305'],
#   [218, 298, 'FCC001306'],
#   [219, 299, 'FCC001307'],
#   [220, 300, 'FCC001300'],
#   [221, 301, 'FCC001301'],
#   [222, 302, 'FCC001302'],
#   [223, 303, 'FCC001303'],
#   [240, 304, 'FCC001512'],
#   [241, 305, 'FCC001513'],
#   [242, 306, 'FCC001514'],
#   [243, 307, 'FCC001515'],
#   [244, 308, 'FCC001508'],
#   [245, 309, 'FCC001509'],
#   [246, 310, 'FCC001510'],
#   [247, 311, 'FCC001511'],
#   [248, 312, 'FCC001504'],
#   [249, 313, 'FCC001505'],
#   [250, 314, 'FCC001506'],
#   [251, 315, 'FCC001507'],
#   [252, 316, 'FCC001500'],
#   [253, 317, 'FCC001501'],
#   [254, 318, 'FCC001502'],
#   [255, 319, 'FCC001503'],
#   [400, 320, 'FCC010912'],
#   [401, 321, 'FCC010913'],
#   [402, 322, 'FCC010914'],
#   [403, 323, 'FCC010915'],
#   [404, 324, 'FCC010908'],
#   [405, 325, 'FCC010909'],
#   [406, 326, 'FCC010910'],
#   [407, 327, 'FCC010911'],
#   [408, 328, 'FCC010904'],
#   [409, 329, 'FCC010905'],
#   [410, 330, 'FCC010906'],
#   [411, 331, 'FCC010907'],
#   [412, 332, 'FCC010900'],
#   [413, 333, 'FCC010901'],
#   [414, 334, 'FCC010902'],
#   [415, 335, 'FCC010903'],
#   [432, 336, 'FCC011112'],
#   [433, 337, 'FCC011113'],
#   [434, 338, 'FCC011114'],
#   [435, 339, 'FCC011115'],
#   [436, 340, 'FCC011108'],
#   [437, 341, 'FCC011109'],
#   [438, 342, 'FCC011110'],
#   [439, 343, 'FCC011111'],
#   [440, 344, 'FCC011104'],
#   [441, 345, 'FCC011105'],
#   [442, 346, 'FCC011106'],
#   [443, 347, 'FCC011107'],
#   [444, 348, 'FCC011100'],
#   [445, 349, 'FCC011101'],
#   [446, 350, 'FCC011102'],
#   [447, 351, 'FCC011103'],
#   [464, 352, 'FCC011312'],
#   [465, 353, 'FCC011313'],
#   [466, 354, 'FCC011314'],
#   [467, 355, 'FCC011315'],
#   [468, 356, 'FCC011308'],
#   [469, 357, 'FCC011309'],
#   [470, 358, 'FCC011310'],
#   [471, 359, 'FCC011311'],
#   [472, 360, 'FCC011304'],
#   [473, 361, 'FCC011305'],
#   [474, 362, 'FCC011306'],
#   [475, 363, 'FCC011307'],
#   [476, 364, 'FCC011300'],
#   [477, 365, 'FCC011301'],
#   [478, 366, 'FCC011302'],
#   [479, 367, 'FCC011303'],
#   [496, 368, 'FCC011512'],
#   [497, 369, 'FCC011513'],
#   [498, 370, 'FCC011514'],
#   [499, 371, 'FCC011515'],
#   [500, 372, 'FCC011508'],
#   [501, 373, 'FCC011509'],
#   [502, 374, 'FCC011510'],
#   [503, 375, 'FCC011511'],
#   [504, 376, 'FCC011504'],
#   [505, 377, 'FCC011505'],
#   [506, 378, 'FCC011506'],
#   [507, 379, 'FCC011507'],
#   [508, 380, 'FCC011500'],
#   [509, 381, 'FCC011501'],
#   [510, 382, 'FCC011502'],
#   [511, 383, 'FCC011503'],
#   [287, 384, 'FCC010103'],
#   [286, 385, 'FCC010102'],
#   [285, 386, 'FCC010101'],
#   [284, 387, 'FCC010100'],
#   [280, 388, 'FCC010104'],
#   [281, 389, 'FCC010105'],
#   [282, 390, 'FCC010106'],
#   [283, 391, 'FCC010107'],
#   [276, 392, 'FCC010108'],
#   [277, 393, 'FCC010109'],
#   [278, 394, 'FCC010110'],
#   [279, 395, 'FCC010111'],
#   [272, 396, 'FCC010112'],
#   [273, 397, 'FCC010113'],
#   [274, 398, 'FCC010114'],
#   [275, 399, 'FCC010115'],
#   [316, 400, 'FCC010300'],
#   [317, 401, 'FCC010301'],
#   [318, 402, 'FCC010302'],
#   [319, 403, 'FCC010303'],
#   [312, 404, 'FCC010304'],
#   [313, 405, 'FCC010305'],
#   [314, 406, 'FCC010306'],
#   [315, 407, 'FCC010307'],
#   [308, 408, 'FCC010308'],
#   [309, 409, 'FCC010309'],
#   [310, 410, 'FCC010310'],
#   [311, 411, 'FCC010311'],
#   [304, 412, 'FCC010312'],
#   [305, 413, 'FCC010313'],
#   [306, 414, 'FCC010314'],
#   [307, 415, 'FCC010315'],
#   [348, 416, 'FCC010500'],
#   [349, 417, 'FCC010501'],
#   [350, 418, 'FCC010502'],
#   [351, 419, 'FCC010503'],
#   [344, 420, 'FCC010504'],
#   [345, 421, 'FCC010505'],
#   [346, 422, 'FCC010506'],
#   [347, 423, 'FCC010507'],
#   [343, 424, 'FCC010511'],
#   [342, 425, 'FCC010510'],
#   [341, 426, 'FCC010509'],
#   [340, 427, 'FCC010508'],
#   [336, 428, 'FCC010512'],
#   [337, 429, 'FCC010513'],
#   [338, 430, 'FCC010514'],
#   [339, 431, 'FCC010515'],
#   [380, 432, 'FCC010700'],
#   [381, 433, 'FCC010701'],
#   [382, 434, 'FCC010702'],
#   [383, 435, 'FCC010703'],
#   [376, 436, 'FCC010704'],
#   [377, 437, 'FCC010705'],
#   [378, 438, 'FCC010706'],
#   [379, 439, 'FCC010707'],
#   [372, 440, 'FCC010708'],
#   [373, 441, 'FCC010709'],
#   [374, 442, 'FCC010710'],
#   [375, 443, 'FCC010711'],
#   [368, 444, 'FCC010712'],
#   [369, 445, 'FCC010713'],
#   [370, 446, 'FCC010714'],
#   [371, 447, 'FCC010715'],
#   [28, 448, 'FCC000100'],
#   [29, 449, 'FCC000101'],
#   [30, 450, 'FCC000102'],
#   [31, 451, 'FCC000103'],
#   [24, 452, 'FCC000104'],
#   [25, 453, 'FCC000105'],
#   [26, 454, 'FCC000106'],
#   [27, 455, 'FCC000107'],
#   [20, 456, 'FCC000108'],
#   [21, 457, 'FCC000109'],
#   [22, 458, 'FCC000110'],
#   [23, 459, 'FCC000111'],
#   [16, 460, 'FCC000112'],
#   [17, 461, 'FCC000113'],
#   [18, 462, 'FCC000114'],
#   [19, 463, 'FCC000115'],
#   [60, 464, 'FCC000300'],
#   [61, 465, 'FCC000301'],
#   [62, 466, 'FCC000302'],
#   [63, 467, 'FCC000303'],
#   [56, 468, 'FCC000304'],
#   [57, 469, 'FCC000305'],
#   [58, 470, 'FCC000306'],
#   [59, 471, 'FCC000307'],
#   [52, 472, 'FCC000308'],
#   [53, 473, 'FCC000309'],
#   [54, 474, 'FCC000310'],
#   [55, 475, 'FCC000311'],
#   [48, 476, 'FCC000312'],
#   [49, 477, 'FCC000313'],
#   [50, 478, 'FCC000314'],
#   [51, 479, 'FCC000315'],
#   [92, 480, 'FCC000500'],
#   [93, 481, 'FCC000501'],
#   [94, 482, 'FCC000502'],
#   [95, 483, 'FCC000503'],
#   [88, 484, 'FCC000504'],
#   [89, 485, 'FCC000505'],
#   [90, 486, 'FCC000506'],
#   [91, 487, 'FCC000507'],
#   [84, 488, 'FCC000508'],
#   [85, 489, 'FCC000509'],
#   [86, 490, 'FCC000510'],
#   [87, 491, 'FCC000511'],
#   [80, 492, 'FCC000512'],
#   [81, 493, 'FCC000513'],
#   [82, 494, 'FCC000514'],
#   [83, 495, 'FCC000515'],
#   [124, 496, 'FCC000700'],
#   [125, 497, 'FCC000701'],
#   [126, 498, 'FCC000702'],
#   [127, 499, 'FCC000703'],
#   [120, 500, 'FCC000704'],
#   [121, 501, 'FCC000705'],
#   [122, 502, 'FCC000706'],
#   [123, 503, 'FCC000707'],
#   [116, 504, 'FCC000708'],
#   [117, 505, 'FCC000709'],
#   [118, 506, 'FCC000710'],
#   [119, 507, 'FCC000711'],
#   [112, 508, 'FCC000712'],
#   [113, 509, 'FCC000713'],
#   [114, 510, 'FCC000714'],
#   [115, 511, 'FCC000715'],
#   [608, 512, 'FCC020612'],
#   [609, 513, 'FCC020613'],
#   [610, 514, 'FCC020614'],
#   [611, 515, 'FCC020615'],
#   [612, 516, 'FCC020608'],
#   [613, 517, 'FCC020609'],
#   [614, 518, 'FCC020610'],
#   [615, 519, 'FCC020611'],
#   [616, 520, 'FCC020604'],
#   [617, 521, 'FCC020605'],
#   [618, 522, 'FCC020606'],
#   [619, 523, 'FCC020607'],
#   [620, 524, 'FCC020600'],
#   [621, 525, 'FCC020601'],
#   [622, 526, 'FCC020602'],
#   [623, 527, 'FCC020603'],
#   [576, 528, 'FCC020412'],
#   [577, 529, 'FCC020413'],
#   [578, 530, 'FCC020414'],
#   [579, 531, 'FCC020415'],
#   [580, 532, 'FCC020408'],
#   [581, 533, 'FCC020409'],
#   [582, 534, 'FCC020410'],
#   [583, 535, 'FCC020411'],
#   [584, 536, 'FCC020404'],
#   [585, 537, 'FCC020405'],
#   [586, 538, 'FCC020406'],
#   [587, 539, 'FCC020407'],
#   [588, 540, 'FCC020400'],
#   [589, 541, 'FCC020401'],
#   [590, 542, 'FCC020402'],
#   [591, 543, 'FCC020403'],
#   [544, 544, 'FCC020212'],
#   [545, 545, 'FCC020213'],
#   [546, 546, 'FCC020214'],
#   [547, 547, 'FCC020215'],
#   [548, 548, 'FCC020208'],
#   [549, 549, 'FCC020209'],
#   [550, 550, 'FCC020210'],
#   [551, 551, 'FCC020211'],
#   [553, 552, 'FCC020205'],
#   [552, 553, 'FCC020204'],
#   [554, 554, 'FCC020206'],
#   [555, 555, 'FCC020207'],
#   [556, 556, 'FCC020200'],
#   [557, 557, 'FCC020201'],
#   [558, 558, 'FCC020202'],
#   [559, 559, 'FCC020203'],
#   [512, 560, 'FCC020012'],
#   [513, 561, 'FCC020013'],
#   [514, 562, 'FCC020014'],
#   [515, 563, 'FCC020015'],
#   [516, 564, 'FCC020008'],
#   [517, 565, 'FCC020009'],
#   [518, 566, 'FCC020010'],
#   [519, 567, 'FCC020011'],
#   [520, 568, 'FCC020004'],
#   [521, 569, 'FCC020005'],
#   [522, 570, 'FCC020006'],
#   [523, 571, 'FCC020007'],
#   [524, 572, 'FCC020000'],
#   [525, 573, 'FCC020001'],
#   [526, 574, 'FCC020002'],
#   [527, 575, 'FCC020003'],
#   [864, 576, 'FCC030612'],
#   [865, 577, 'FCC030613'],
#   [866, 578, 'FCC030614'],
#   [867, 579, 'FCC030615'],
#   [868, 580, 'FCC030608'],
#   [869, 581, 'FCC030609'],
#   [870, 582, 'FCC030610'],
#   [871, 583, 'FCC030611'],
#   [872, 584, 'FCC030604'],
#   [873, 585, 'FCC030605'],
#   [874, 586, 'FCC030606'],
#   [875, 587, 'FCC030607'],
#   [876, 588, 'FCC030600'],
#   [877, 589, 'FCC030601'],
#   [878, 590, 'FCC030602'],
#   [879, 591, 'FCC030603'],
#   [832, 592, 'FCC030412'],
#   [833, 593, 'FCC030413'],
#   [834, 594, 'FCC030414'],
#   [835, 595, 'FCC030415'],
#   [836, 596, 'FCC030408'],
#   [837, 597, 'FCC030409'],
#   [838, 598, 'FCC030410'],
#   [839, 599, 'FCC030411'],
#   [840, 600, 'FCC030404'],
#   [841, 601, 'FCC030405'],
#   [842, 602, 'FCC030406'],
#   [843, 603, 'FCC030407'],
#   [844, 604, 'FCC030400'],
#   [845, 605, 'FCC030401'],
#   [846, 606, 'FCC030402'],
#   [847, 607, 'FCC030403'],
#   [800, 608, 'FCC030212'],
#   [801, 609, 'FCC030213'],
#   [802, 610, 'FCC030214'],
#   [803, 611, 'FCC030215'],
#   [804, 612, 'FCC030208'],
#   [805, 613, 'FCC030209'],
#   [806, 614, 'FCC030210'],
#   [807, 615, 'FCC030211'],
#   [808, 616, 'FCC030204'],
#   [809, 617, 'FCC030205'],
#   [810, 618, 'FCC030206'],
#   [811, 619, 'FCC030207'],
#   [812, 620, 'FCC030200'],
#   [813, 621, 'FCC030201'],
#   [814, 622, 'FCC030202'],
#   [815, 623, 'FCC030203'],
#   [768, 624, 'FCC030012'],
#   [769, 625, 'FCC030013'],
#   [770, 626, 'FCC030014'],
#   [771, 627, 'FCC030015'],
#   [772, 628, 'FCC030008'],
#   [773, 629, 'FCC030009'],
#   [774, 630, 'FCC030010'],
#   [775, 631, 'FCC030011'],
#   [776, 632, 'FCC030004'],
#   [777, 633, 'FCC030005'],
#   [778, 634, 'FCC030006'],
#   [779, 635, 'FCC030007'],
#   [780, 636, 'FCC030000'],
#   [781, 637, 'FCC030001'],
#   [782, 638, 'FCC030002'],
#   [783, 639, 'FCC030003'],
#   [1004, 640, 'FCC031400'],
#   [1005, 641, 'FCC031401'],
#   [1006, 642, 'FCC031402'],
#   [1007, 643, 'FCC031403'],
#   [1003, 644, 'FCC031407'],
#   [1002, 645, 'FCC031406'],
#   [1001, 646, 'FCC031405'],
#   [1000, 647, 'FCC031404'],
#   [996, 648, 'FCC031408'],
#   [997, 649, 'FCC031409'],
#   [934, 650, 'FCC031010'],
#   [935, 651, 'FCC031011'],
#   [992, 652, 'FCC031412'],
#   [993, 653, 'FCC031413'],
#   [994, 654, 'FCC031414'],
#   [995, 655, 'FCC031415'],
#   [972, 656, 'FCC031200'],
#   [973, 657, 'FCC031201'],
#   [974, 658, 'FCC031202'],
#   [975, 659, 'FCC031203'],
#   [968, 660, 'FCC031204'],
#   [969, 661, 'FCC031205'],
#   [970, 662, 'FCC031206'],
#   [971, 663, 'FCC031207'],
#   [964, 664, 'FCC031208'],
#   [965, 665, 'FCC031209'],
#   [966, 666, 'FCC031210'],
#   [967, 667, 'FCC031211'],
#   [960, 668, 'FCC031212'],
#   [961, 669, 'FCC031213'],
#   [962, 670, 'FCC031214'],
#   [963, 671, 'FCC031215'],
#   [943, 672, 'FCC031003'],
#   [942, 673, 'FCC031002'],
#   [941, 674, 'FCC031001'],
#   [940, 675, 'FCC031000'],
#   [936, 676, 'FCC031004'],
#   [937, 677, 'FCC031005'],
#   [938, 678, 'FCC031006'],
#   [939, 679, 'FCC031007'],
#   [932, 680, 'FCC031008'],
#   [933, 681, 'FCC031009'],
#   [998, 682, 'FCC031410'],
#   [999, 683, 'FCC031411'],
#   [928, 684, 'FCC031012'],
#   [929, 685, 'FCC031013'],
#   [930, 686, 'FCC031014'],
#   [931, 687, 'FCC031015'],
#   [908, 688, 'FCC030800'],
#   [909, 689, 'FCC030801'],
#   [910, 690, 'FCC030802'],
#   [911, 691, 'FCC030803'],
#   [904, 692, 'FCC030804'],
#   [905, 693, 'FCC030805'],
#   [906, 694, 'FCC030806'],
#   [907, 695, 'FCC030807'],
#   [900, 696, 'FCC030808'],
#   [901, 697, 'FCC030809'],
#   [902, 698, 'FCC030810'],
#   [903, 699, 'FCC030811'],
#   [896, 700, 'FCC030812'],
#   [897, 701, 'FCC030813'],
#   [898, 702, 'FCC030814'],
#   [899, 703, 'FCC030815'],
#   [748, 704, 'FCC021400'],
#   [749, 705, 'FCC021401'],
#   [750, 706, 'FCC021402'],
#   [751, 707, 'FCC021403'],
#   [744, 708, 'FCC021404'],
#   [745, 709, 'FCC021405'],
#   [746, 710, 'FCC021406'],
#   [747, 711, 'FCC021407'],
#   [740, 712, 'FCC021408'],
#   [741, 713, 'FCC021409'],
#   [742, 714, 'FCC021410'],
#   [743, 715, 'FCC021411'],
#   [736, 716, 'FCC021412'],
#   [737, 717, 'FCC021413'],
#   [738, 718, 'FCC021414'],
#   [739, 719, 'FCC021415'],
#   [716, 720, 'FCC021200'],
#   [717, 721, 'FCC021201'],
#   [718, 722, 'FCC021202'],
#   [719, 723, 'FCC021203'],
#   [712, 724, 'FCC021204'],
#   [713, 725, 'FCC021205'],
#   [714, 726, 'FCC021206'],
#   [715, 727, 'FCC021207'],
#   [708, 728, 'FCC021208'],
#   [709, 729, 'FCC021209'],
#   [710, 730, 'FCC021210'],
#   [711, 731, 'FCC021211'],
#   [704, 732, 'FCC021212'],
#   [705, 733, 'FCC021213'],
#   [706, 734, 'FCC021214'],
#   [707, 735, 'FCC021215'],
#   [684, 736, 'FCC021000'],
#   [685, 737, 'FCC021001'],
#   [686, 738, 'FCC021002'],
#   [687, 739, 'FCC021003'],
#   [680, 740, 'FCC021004'],
#   [681, 741, 'FCC021005'],
#   [682, 742, 'FCC021006'],
#   [683, 743, 'FCC021007'],
#   [676, 744, 'FCC021008'],
#   [677, 745, 'FCC021009'],
#   [678, 746, 'FCC021010'],
#   [679, 747, 'FCC021011'],
#   [672, 748, 'FCC021012'],
#   [673, 749, 'FCC021013'],
#   [674, 750, 'FCC021014'],
#   [675, 751, 'FCC021015'],
#   [652, 752, 'FCC020800'],
#   [653, 753, 'FCC020801'],
#   [654, 754, 'FCC020802'],
#   [655, 755, 'FCC020803'],
#   [648, 756, 'FCC020804'],
#   [649, 757, 'FCC020805'],
#   [650, 758, 'FCC020806'],
#   [651, 759, 'FCC020807'],
#   [644, 760, 'FCC020808'],
#   [645, 761, 'FCC020809'],
#   [646, 762, 'FCC020810'],
#   [647, 763, 'FCC020811'],
#   [640, 764, 'FCC020812'],
#   [641, 765, 'FCC020813'],
#   [642, 766, 'FCC020814'],
#   [643, 767, 'FCC020815'],
#   [624, 768, 'FCC020712'],
#   [625, 769, 'FCC020713'],
#   [626, 770, 'FCC020714'],
#   [627, 771, 'FCC020715'],
#   [628, 772, 'FCC020708'],
#   [629, 773, 'FCC020709'],
#   [630, 774, 'FCC020710'],
#   [631, 775, 'FCC020711'],
#   [632, 776, 'FCC020704'],
#   [633, 777, 'FCC020705'],
#   [634, 778, 'FCC020706'],
#   [635, 779, 'FCC020707'],
#   [636, 780, 'FCC020700'],
#   [637, 781, 'FCC020701'],
#   [638, 782, 'FCC020702'],
#   [639, 783, 'FCC020703'],
#   [592, 784, 'FCC020512'],
#   [593, 785, 'FCC020513'],
#   [594, 786, 'FCC020514'],
#   [595, 787, 'FCC020515'],
#   [596, 788, 'FCC020508'],
#   [597, 789, 'FCC020509'],
#   [598, 790, 'FCC020510'],
#   [599, 791, 'FCC020511'],
#   [600, 792, 'FCC020504'],
#   [601, 793, 'FCC020505'],
#   [602, 794, 'FCC020506'],
#   [603, 795, 'FCC020507'],
#   [604, 796, 'FCC020500'],
#   [605, 797, 'FCC020501'],
#   [606, 798, 'FCC020502'],
#   [607, 799, 'FCC020503'],
#   [560, 800, 'FCC020312'],
#   [561, 801, 'FCC020313'],
#   [562, 802, 'FCC020314'],
#   [563, 803, 'FCC020315'],
#   [564, 804, 'FCC020308'],
#   [565, 805, 'FCC020309'],
#   [566, 806, 'FCC020310'],
#   [567, 807, 'FCC020311'],
#   [568, 808, 'FCC020304'],
#   [569, 809, 'FCC020305'],
#   [570, 810, 'FCC020306'],
#   [571, 811, 'FCC020307'],
#   [572, 812, 'FCC020300'],
#   [573, 813, 'FCC020301'],
#   [574, 814, 'FCC020302'],
#   [575, 815, 'FCC020303'],
#   [528, 816, 'FCC020112'],
#   [529, 817, 'FCC020113'],
#   [530, 818, 'FCC020114'],
#   [531, 819, 'FCC020115'],
#   [532, 820, 'FCC020108'],
#   [533, 821, 'FCC020109'],
#   [534, 822, 'FCC020110'],
#   [535, 823, 'FCC020111'],
#   [536, 824, 'FCC020104'],
#   [537, 825, 'FCC020105'],
#   [538, 826, 'FCC020106'],
#   [539, 827, 'FCC020107'],
#   [540, 828, 'FCC020100'],
#   [541, 829, 'FCC020101'],
#   [542, 830, 'FCC020102'],
#   [543, 831, 'FCC020103'],
#   [880, 832, 'FCC030712'],
#   [881, 833, 'FCC030713'],
#   [882, 834, 'FCC030714'],
#   [883, 835, 'FCC030715'],
#   [884, 836, 'FCC030708'],
#   [885, 837, 'FCC030709'],
#   [886, 838, 'FCC030710'],
#   [887, 839, 'FCC030711'],
#   [888, 840, 'FCC030704'],
#   [889, 841, 'FCC030705'],
#   [890, 842, 'FCC030706'],
#   [891, 843, 'FCC030707'],
#   [892, 844, 'FCC030700'],
#   [893, 845, 'FCC030701'],
#   [894, 846, 'FCC030702'],
#   [895, 847, 'FCC030703'],
#   [848, 848, 'FCC030512'],
#   [849, 849, 'FCC030513'],
#   [850, 850, 'FCC030514'],
#   [851, 851, 'FCC030515'],
#   [852, 852, 'FCC030508'],
#   [853, 853, 'FCC030509'],
#   [854, 854, 'FCC030510'],
#   [855, 855, 'FCC030511'],
#   [856, 856, 'FCC030504'],
#   [857, 857, 'FCC030505'],
#   [858, 858, 'FCC030506'],
#   [859, 859, 'FCC030507'],
#   [860, 860, 'FCC030500'],
#   [861, 861, 'FCC030501'],
#   [862, 862, 'FCC030502'],
#   [863, 863, 'FCC030503'],
#   [816, 864, 'FCC030312'],
#   [817, 865, 'FCC030313'],
#   [818, 866, 'FCC030314'],
#   [819, 867, 'FCC030315'],
#   [820, 868, 'FCC030308'],
#   [821, 869, 'FCC030309'],
#   [822, 870, 'FCC030310'],
#   [823, 871, 'FCC030311'],
#   [824, 872, 'FCC030304'],
#   [825, 873, 'FCC030305'],
#   [826, 874, 'FCC030306'],
#   [827, 875, 'FCC030307'],
#   [828, 876, 'FCC030300'],
#   [829, 877, 'FCC030301'],
#   [830, 878, 'FCC030302'],
#   [831, 879, 'FCC030303'],
#   [784, 880, 'FCC030112'],
#   [785, 881, 'FCC030113'],
#   [786, 882, 'FCC030114'],
#   [787, 883, 'FCC030115'],
#   [788, 884, 'FCC030108'],
#   [789, 885, 'FCC030109'],
#   [790, 886, 'FCC030110'],
#   [791, 887, 'FCC030111'],
#   [792, 888, 'FCC030104'],
#   [793, 889, 'FCC030105'],
#   [794, 890, 'FCC030106'],
#   [795, 891, 'FCC030107'],
#   [796, 892, 'FCC030100'],
#   [797, 893, 'FCC030101'],
#   [798, 894, 'FCC030102'],
#   [799, 895, 'FCC030103'],
#   [1020, 896, 'FCC031500'],
#   [1021, 897, 'FCC031501'],
#   [1022, 898, 'FCC031502'],
#   [1023, 899, 'FCC031503'],
#   [1016, 900, 'FCC031504'],
#   [1017, 901, 'FCC031505'],
#   [1018, 902, 'FCC031506'],
#   [1019, 903, 'FCC031507'],
#   [1012, 904, 'FCC031508'],
#   [1013, 905, 'FCC031509'],
#   [1015, 906, 'FCC031511'],
#   [1014, 907, 'FCC031510'],
#   [1008, 908, 'FCC031512'],
#   [1009, 909, 'FCC031513'],
#   [1010, 910, 'FCC031514'],
#   [1011, 911, 'FCC031515'],
#   [988, 912, 'FCC031300'],
#   [989, 913, 'FCC031301'],
#   [990, 914, 'FCC031302'],
#   [991, 915, 'FCC031303'],
#   [984, 916, 'FCC031304'],
#   [985, 917, 'FCC031305'],
#   [986, 918, 'FCC031306'],
#   [987, 919, 'FCC031307'],
#   [980, 920, 'FCC031308'],
#   [981, 921, 'FCC031309'],
#   [982, 922, 'FCC031310'],
#   [983, 923, 'FCC031311'],
#   [976, 924, 'FCC031312'],
#   [977, 925, 'FCC031313'],
#   [978, 926, 'FCC031314'],
#   [979, 927, 'FCC031315'],
#   [956, 928, 'FCC031100'],
#   [957, 929, 'FCC031101'],
#   [958, 930, 'FCC031102'],
#   [959, 931, 'FCC031103'],
#   [952, 932, 'FCC031104'],
#   [953, 933, 'FCC031105'],
#   [954, 934, 'FCC031106'],
#   [955, 935, 'FCC031107'],
#   [948, 936, 'FCC031108'],
#   [949, 937, 'FCC031109'],
#   [950, 938, 'FCC031110'],
#   [951, 939, 'FCC031111'],
#   [944, 940, 'FCC031112'],
#   [945, 941, 'FCC031113'],
#   [946, 942, 'FCC031114'],
#   [947, 943, 'FCC031115'],
#   [924, 944, 'FCC030900'],
#   [925, 945, 'FCC030901'],
#   [926, 946, 'FCC030902'],
#   [927, 947, 'FCC030903'],
#   [920, 948, 'FCC030904'],
#   [921, 949, 'FCC030905'],
#   [922, 950, 'FCC030906'],
#   [923, 951, 'FCC030907'],
#   [916, 952, 'FCC030908'],
#   [917, 953, 'FCC030909'],
#   [918, 954, 'FCC030910'],
#   [919, 955, 'FCC030911'],
#   [912, 956, 'FCC030912'],
#   [913, 957, 'FCC030913'],
#   [914, 958, 'FCC030914'],
#   [915, 959, 'FCC030915'],
#   [764, 960, 'FCC021500'],
#   [765, 961, 'FCC021501'],
#   [766, 962, 'FCC021502'],
#   [767, 963, 'FCC021503'],
#   [760, 964, 'FCC021504'],
#   [761, 965, 'FCC021505'],
#   [762, 966, 'FCC021506'],
#   [763, 967, 'FCC021507'],
#   [756, 968, 'FCC021508'],
#   [757, 969, 'FCC021509'],
#   [758, 970, 'FCC021510'],
#   [759, 971, 'FCC021511'],
#   [752, 972, 'FCC021512'],
#   [753, 973, 'FCC021513'],
#   [754, 974, 'FCC021514'],
#   [755, 975, 'FCC021515'],
#   [732, 976, 'FCC021300'],
#   [733, 977, 'FCC021301'],
#   [734, 978, 'FCC021302'],
#   [735, 979, 'FCC021303'],
#   [728, 980, 'FCC021304'],
#   [729, 981, 'FCC021305'],
#   [730, 982, 'FCC021306'],
#   [731, 983, 'FCC021307'],
#   [724, 984, 'FCC021308'],
#   [725, 985, 'FCC021309'],
#   [726, 986, 'FCC021310'],
#   [727, 987, 'FCC021311'],
#   [720, 988, 'FCC021312'],
#   [721, 989, 'FCC021313'],
#   [722, 990, 'FCC021314'],
#   [723, 991, 'FCC021315'],
#   [700, 992, 'FCC021100'],
#   [701, 993, 'FCC021101'],
#   [702, 994, 'FCC021102'],
#   [703, 995, 'FCC021103'],
#   [696, 996, 'FCC021104'],
#   [697, 997, 'FCC021105'],
#   [698, 998, 'FCC021106'],
#   [699, 999, 'FCC021107'],
#   ...],
#  'power_supplies': {'servers': {'pss0': {'hostname': 'carillon',
#     'port': 54324,
#     'units': {'ps_crate0': {'type': 'AgilentN5764',
#       'hostname': '10.0.0.30',
#       'timeout': 2,
#       'power_up_delay': 70},
#      'ps_crate1': {'type': 'AgilentN5764',
#       'hostname': '10.0.0.31',
#       'timeout': 2,
#       'power_up_delay': 70},
#      'ps_crate2': {'type': 'AgilentN5764',
#       'hostname': '10.0.0.32',
#       'timeout': 2,
#       'power_up_delay': 70},
#      'ps_crate3': {'type': 'AgilentN5764',
#       'hostname': '10.0.0.33',
#       'timeout': 2,
#       'power_up_delay': 70},
#      'ps_crate4': {'type': 'AgilentN5764',
#       'hostname': '10.0.0.34',
#       'timeout': 2,
#       'power_up_delay': 70},
#      'ps_crate5': {'type': 'AgilentN5764',
#       'hostname': '10.0.0.35',
#       'timeout': 2,
#       'power_up_delay': 70},
#      'ps_crate6': {'type': 'AgilentN5764',
#       'hostname': '10.0.0.36',
#       'timeout': 2,
#       'power_up_delay': 70},
#      'ps_crate7': {'type': 'AgilentN5764',
#       'hostname': '10.0.0.37',
#       'timeout': 2,
#       'power_up_delay': 70},
#      'FLA_east': {'type': 'AgilentN8731',
#       'hostname': '10.0.0.40',
#       'timeout': 2,
#       'power_up_delay': 70},
#      'FLA_west': {'type': 'AgilentN8731',
#       'hostname': '10.0.0.41',
#       'timeout': 2,
#       'power_up_delay': 70}},
#     'aliases': {'c0': ['ps_crate0'],
#      'c1': ['ps_crate1'],
#      'c2': ['ps_crate2'],
#      'c3': ['ps_crate3'],
#      'c4': ['ps_crate4'],
#      'c5': ['ps_crate5'],
#      'c6': ['ps_crate6'],
#      'c7': ['ps_crate7'],
#      'c8': ['ps_crate8'],
#      'c9': ['ps_crate9'],
#      'c01': ['ps_crate0', 'ps_crate1'],
#      'c23': ['ps_crate2', 'ps_crate3'],
#      'c45': ['ps_crate4', 'ps_crate5'],
#      'c67': ['ps_crate6', 'ps_crate7'],
#      'wrh': ['ps_crate0', 'ps_crate1', 'ps_crate2', 'ps_crate3', 'FLA_west'],
#      'erh': ['ps_crate4', 'ps_crate5', 'ps_crate6', 'ps_crate7', 'FLA_east'],
#      'full': ['ps_crate0',
#       'ps_crate1',
#       'ps_crate2',
#       'ps_crate3',
#       'ps_crate4',
#       'ps_crate5',
#       'ps_crate6',
#       'ps_crate7']}}},
#   'power_on': {'units': ['ps_crate0',
#     'ps_crate1',
#     'ps_crate2',
#     'ps_crate3',
#     'ps_crate4',
#     'ps_crate5',
#     'ps_crate6',
#     'ps_crate7']}},
#  'enable_gain_switching': False,
#  'fpga': {'fpga_array_params': {'hwm': [{'class': 'IceCrate_MGK7BP16',
#      'serial': '021',
#      'crate_number': 0},
#     {'class': 'IceCrate_MGK7BP16', 'serial': '024', 'crate_number': 1},
#     {'class': 'IceCrate_MGK7BP16', 'serial': '028', 'crate_number': 2},
#     {'class': 'IceCrate_MGK7BP16', 'serial': '019', 'crate_number': 3},
#     {'class': 'IceCrate_MGK7BP16', 'serial': '018', 'crate_number': 4},
#     {'class': 'IceCrate_MGK7BP16', 'serial': '023', 'crate_number': 5},
#     {'class': 'IceCrate_MGK7BP16', 'serial': '011', 'crate_number': 6},
#     {'class': 'IceCrate_MGK7BP16', 'serial': '020', 'crate_number': 7},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.1',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 1},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.2',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 2},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.3',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 3},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.4',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 4},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.5',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 5},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.6',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 6},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.7',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 7},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.8',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 8},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.9',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 9},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.10',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 10},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.11',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 11},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.12',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 12},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.13',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 13},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.14',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 14},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.15',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 15},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.16',
#      'subarray': 0,
#      'crate_number': 0,
#      'slot': 16},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.82',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 1},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.18',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 2},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.19',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 3},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.20',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 4},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.21',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 5},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.22',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 6},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.23',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 7},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.24',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 8},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.25',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 9},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.26',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 10},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.27',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 11},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.28',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 12},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.29',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 13},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.30',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 14},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.31',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 15},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.32',
#      'subarray': 1,
#      'crate_number': 1,
#      'slot': 16},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.33',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 1},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.34',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 2},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.35',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 3},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.36',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 4},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.37',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 5},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.113',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 6},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.39',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 7},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.40',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 8},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.41',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 9},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.42',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 10},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.43',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 11},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.44',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 12},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.45',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 13},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.46',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 14},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.47',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 15},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.48',
#      'subarray': 2,
#      'crate_number': 2,
#      'slot': 16},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.49',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 1},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.50',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 2},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.51',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 3},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.52',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 4},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.53',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 5},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.54',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 6},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.55',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 7},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.56',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 8},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.57',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 9},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.58',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 10},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.59',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 11},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.60',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 12},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.61',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 13},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.62',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 14},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.63',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 15},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.64',
#      'subarray': 3,
#      'crate_number': 3,
#      'slot': 16},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.65',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 1},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.66',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 2},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.67',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 3},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.68',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 4},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.69',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 5},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.70',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 6},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.71',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 7},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.72',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 8},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.73',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 9},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.74',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 10},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.75',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 11},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.76',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 12},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.77',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 13},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.78',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 14},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.79',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 15},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.80',
#      'subarray': 4,
#      'crate_number': 4,
#      'slot': 16},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.81',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 1},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.1.151',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 2},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.83',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 3},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.84',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 4},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.85',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 5},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.86',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 6},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.87',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 7},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.88',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 8},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.89',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 9},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.90',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 10},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.91',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 11},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.92',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 12},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.93',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 13},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.94',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 14},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.95',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 15},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.96',
#      'subarray': 5,
#      'crate_number': 5,
#      'slot': 16},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.97',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 1},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.98',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 2},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.99',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 3},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.100',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 4},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.101',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 5},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.102',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 6},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.103',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 7},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.104',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 8},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.105',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 9},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.106',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 10},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.107',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 11},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.108',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 12},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.109',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 13},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.110',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 14},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.111',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 15},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.112',
#      'subarray': 6,
#      'crate_number': 6,
#      'slot': 16},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.114',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 1},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.1.150',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 2},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.115',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 3},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.116',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 4},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.117',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 5},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.118',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 6},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.119',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 7},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.120',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 8},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.121',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 9},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.122',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 10},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.124',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 11},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.1.38',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 12},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.125',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 13},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.126',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 14},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.127',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 15},
#     {'class': 'chFPGA_controller',
#      'hostname': '10.0.2.128',
#      'subarray': 7,
#      'crate_number': 7,
#      'slot': 16}],
#    'mode': 'shuffle512',
#    'prog': 2,
#    'open': 1,
#    'frames_per_packet': 2,
#    'samp_freq': 800,
#    'sync_method': 'distributed_time',
#    'sync_source': 'bp_time',
#    'sync_master': None,
#    'sync_master_time_source': None,
#    'tx_power': {'corner_turn': [{'lane_group': 'pcb',
#       'default': [7, 13],
#       'exceptions': [[[7, 6, 2], [10, 15]],
#        [[0, 9, 6], [10, 15]],
#        [[6, 9, 6], [10, 15]],
#        [[2, 9, 6], [10, 15]],
#        [[2, 9, 10], [10, 15]]]},
#      {'lane_group': 'qsfp', 'default': [10, 15]}]},
#    'corner_turn_remap_level': 3,
#    'corner_turn_bad_links': [[1, 12, 7],
#     [0, 13, 7],
#     [1, 7, 0],
#     [0, 0, 6],
#     [1, 12, 2],
#     [0, 12, 5],
#     [0, 10, 4],
#     [0, 2, 2],
#     [0, 5, 6],
#     [1, 6, 5],
#     [1, 2, 1],
#     [0, 8, 3],
#     [1, 15, 3],
#     [0, 0, 2],
#     [1, 5, 0],
#     [1, 11, 5],
#     [1, 12, 6],
#     [1, 15, 2],
#     [1, 10, 0],
#     [1, 0, 2],
#     [0, 11, 7],
#     [1, 1, 2],
#     [0, 12, 7],
#     [1, 4, 5],
#     [0, 11, 1],
#     [1, 3, 3],
#     [0, 14, 3],
#     [1, 5, 3],
#     [0, 2, 1],
#     [1, 8, 4],
#     [0, 11, 2],
#     [1, 4, 1],
#     [1, 14, 0],
#     [0, 4, 0],
#     [1, 2, 2],
#     [1, 2, 3]],
#    'corner_turn_bin_priority': [274,
#     388,
#     284,
#     287,
#     375,
#     288,
#     676,
#     372,
#     415,
#     786,
#     382,
#     63,
#     383,
#     380,
#     876,
#     884,
#     404,
#     811,
#     370,
#     796,
#     373,
#     666,
#     474,
#     275,
#     280,
#     279,
#     277,
#     298,
#     263,
#     282,
#     300,
#     262,
#     303,
#     295,
#     296,
#     285,
#     281,
#     291,
#     265,
#     299,
#     304,
#     289,
#     260,
#     182,
#     311,
#     181,
#     183,
#     191,
#     261,
#     325,
#     310,
#     190,
#     309,
#     185,
#     187,
#     308,
#     305,
#     301,
#     326,
#     294,
#     416,
#     413,
#     423,
#     302,
#     322,
#     186,
#     422,
#     292,
#     193,
#     188,
#     194,
#     765,
#     324,
#     323,
#     329,
#     418,
#     339,
#     426,
#     332,
#     330,
#     192,
#     351,
#     306,
#     184,
#     371,
#     316,
#     320,
#     312,
#     763,
#     437,
#     315,
#     761,
#     318,
#     317,
#     258,
#     414,
#     762,
#     340,
#     319,
#     195,
#     403,
#     327,
#     365,
#     290,
#     331,
#     361,
#     179,
#     417,
#     366,
#     424,
#     313,
#     314,
#     334,
#     335,
#     321,
#     336,
#     337,
#     307,
#     402,
#     201,
#     428,
#     420,
#     341,
#     410,
#     438,
#     436,
#     362,
#     328,
#     367,
#     406,
#     407,
#     368,
#     425,
#     489,
#     81,
#     197,
#     198,
#     202,
#     1018,
#     376,
#     439,
#     490,
#     429,
#     419,
#     479,
#     393,
#     395,
#     760,
#     409,
#     80,
#     342,
#     360,
#     431,
#     196,
#     354,
#     434,
#     401,
#     486,
#     480,
#     358,
#     350,
#     442,
#     408,
#     369,
#     435,
#     359,
#     396,
#     481,
#     392,
#     1,
#     482,
#     473,
#     364,
#     470,
#     355,
#     421,
#     352,
#     345,
#     200,
#     82,
#     398,
#     67,
#     338,
#     266,
#     257,
#     349,
#     768,
#     83,
#     411,
#     427,
#     487,
#     477,
#     432,
#     472,
#     433,
#     488,
#     66,
#     484,
#     441,
#     356,
#     363,
#     397,
#     430,
#     443,
#     476,
#     440,
#     630,
#     471,
#     491,
#     385,
#     348,
#     344,
#     70,
#     483,
#     92,
#     478,
#     74,
#     86,
#     394,
#     405,
#     189,
#     535,
#     78,
#     941,
#     73,
#     353,
#     949,
#     948,
#     3,
#     333,
#     2,
#     723,
#     84,
#     357,
#     570,
#     75,
#     10,
#     8,
#     533,
#     203,
#     971,
#     93,
#     98,
#     85,
#     571,
#     87,
#     574,
#     531,
#     89,
#     969,
#     694,
#     942,
#     11,
#     695,
#     259,
#     532,
#     71,
#     693,
#     579,
#     647,
#     947,
#     700,
#     726,
#     65,
#     576,
#     950,
#     551,
#     651,
#     17,
#     727,
#     550,
#     965,
#     728,
#     347,
#     520,
#     958,
#     957,
#     649,
#     99,
#     970,
#     940,
#     578,
#     581,
#     609,
#     412,
#     544,
#     14,
#     573,
#     548,
#     76,
#     955,
#     580,
#     25,
#     199,
#     21,
#     925,
#     960,
#     724,
#     13,
#     525,
#     963,
#     611,
#     577,
#     12,
#     607,
#     701,
#     730,
#     653,
#     346,
#     697,
#     699,
#     956,
#     91,
#     735,
#     26,
#     648,
#     18,
#     652,
#     621,
#     88,
#     702,
#     343,
#     984,
#     7,
#     628,
#     547,
#     541,
#     698,
#     980,
#     15,
#     922,
#     545,
#     968,
#     696,
#     605,
#     16,
#     620,
#     293,
#     542,
#     732,
#     729,
#     524,
#     6,
#     600,
#     670,
#     606,
#     530,
#     692,
#     608,
#     96,
#     769,
#     954,
#     612,
#     97,
#     5,
#     669,
#     625,
#     953,
#     536,
#     705,
#     733,
#     943,
#     674,
#     672,
#     610,
#     654,
#     582,
#     656,
#     658,
#     939,
#     703,
#     101,
#     100,
#     389,
#     619,
#     618,
#     951,
#     985,
#     983,
#     982,
#     671,
#     540,
#     917,
#     979,
#     391,
#     659,
#     617,
#     622,
#     919,
#     924,
#     511,
#     952,
#     964,
#     751,
#     624,
#     673,
#     737,
#     668,
#     626,
#     662,
#     936,
#     51,
#     627,
#     72,
#     538,
#     655,
#     103,
#     938,
#     623,
#     704,
#     946,
#     616,
#     981,
#     912,
#     546,
#     661,
#     94,
#     663,
#     665,
#     102,
#     386,
#     529,
#     994,
#     206,
#     603,
#     748,
#     534,
#     667,
#     962,
#     744,
#     1015,
#     736,
#     750,
#     523,
#     664,
#     742,
#     999,
#     1008,
#     926,
#     743,
#     604,
#     485,
#     745,
#     753,
#     746,
#     52,
#     23,
#     90,
#     513,
#     390,
#     50,
#     993,
#     569,
#     374,
#     1000,
#     650,
#     28,
#     48,
#     749,
#     1010,
#     379,
#     377,
#     95,
#     918,
#     528,
#     543,
#     601,
#     59,
#     747,
#     22,
#     734,
#     208,
#     387,
#     923,
#     209,
#     207,
#     381,
#     740,
#     526,
#     1007,
#     400,
#     935,
#     29,
#     1003,
#     996,
#     527,
#     475,
#     210,
#     211,
#     1012,
#     722,
#     205,
#     911,
#     77,
#     1009,
#     739,
#     549,
#     55,
#     104,
#     378,
#     507,
#     1014,
#     614,
#     212,
#     537,
#     998,
#     896,
#     913,
#     509,
#     508,
#     615,
#     58,
#     914,
#     519,
#     514,
#     107,
#     24,
#     758,
#     976,
#     105,
#     108,
#     675,
#     54,
#     510,
#     1005,
#     522,
#     731,
#     109,
#     967,
#     53,
#     770,
#     792,
#     988,
#     978,
#     646,
#     539,
#     602,
#     741,
#     518,
#     57,
#     106,
#     515,
#     27,
#     492,
#     629,
#     902,
#     517,
#     64,
#     493,
#     1004,
#     516,
#     901,
#     255,
#     56,
#     904,
#     31,
#     738,
#     503,
#     504,
#     500,
#     494,
#     759,
#     215,
#     501,
#     47,
#     499,
#     899,
#     49,
#     495,
#     771,
#     32,
#     898,
#     384,
#     399,
#     496,
#     497,
#     502,
#     62,
#     927,
#     706,
#     19,
#     707,
#     216,
#     61,
#     720,
#     1006,
#     966,
#     110,
#     718,
#     708,
#     714,
#     716,
#     715,
#     719,
#     711,
#     710,
#     30,
#     717,
#     712,
#     505,
#     713,
#     112,
#     709,
#     900,
#     111,
#     921,
#     894,
#     863,
#     4,
#     498,
#     785,
#     20,
#     881,
#     469,
#     250,
#     204,
#     1011,
#     1001,
#     891,
#     944,
#     245,
#     512,
#     725,
#     248,
#     879,
#     240,
#     249,
#     246,
#     239,
#     890,
#     243,
#     251,
#     60,
#     787,
#     905,
#     247,
#     1013,
#     217,
#     790,
#     214,
#     236,
#     252,
#     237,
#     752,
#     238,
#     878,
#     872,
#     945,
#     241,
#     871,
#     213,
#     910,
#     235,
#     797,
#     932,
#     997,
#     973,
#     231,
#     33,
#     972,
#     867,
#     992,
#     784,
#     861,
#     41,
#     893,
#     42,
#     856,
#     866,
#     244,
#     242,
#     995,
#     906,
#     757,
#     853,
#     931,
#     854,
#     254,
#     865,
#     852,
#     218,
#     773,
#     38,
#     506,
#     959,
#     889,
#     40,
#     836,
#     278,
#     837,
#     838,
#     39,
#     833,
#     232,
#     845,
#     832,
#     800,
#     37,
#     841,
#     843,
#     831,
#     851,
#     781,
#     847,
#     830,
#     961,
#     862,
#     842,
#     780,
#     835,
#     989,
#     897,
#     774,
#     834,
#     43,
#     802,
#     839,
#     828,
#     778,
#     827,
#     1002,
#     234,
#     860,
#     783,
#     233,
#     777,
#     826,
#     779,
#     822,
#     776,
#     916,
#     775,
#     868,
#     821,
#     801,
#     934,
#     721,
#     915,
#     844,
#     886,
#     829,
#     36,
#     864,
#     903,
#     820,
#     226,
#     840,
#     817,
#     885,
#     225,
#     804,
#     264,
#     990,
#     227,
#     69,
#     230,
#     803,
#     224,
#     877,
#     818,
#     222,
#     46,
#     223,
#     221,
#     814,
#     286,
#     909,
#     794,
#     977,
#     44,
#     805,
#     888,
#     920,
#     816,
#     140,
#     228,
#     256,
#     795,
#     870,
#     824,
#     35,
#     220,
#     933,
#     857,
#     975,
#     1023,
#     139,
#     815,
#     813,
#     825,
#     930,
#     812,
#     1022,
#     849,
#     806,
#     873,
#     276,
#     271,
#     272,
#     819,
#     850,
#     907,
#     1020,
#     1019,
#     755,
#     908,
#     986,
#     269,
#     987,
#     928,
#     793,
#     823,
#     929,
#     219,
#     1021,
#     887,
#     229,
#     880,
#     613,
#     807,
#     270,
#     974,
#     45,
#     34,
#     874,
#     892,
#     859,
#     883,
#     1016,
#     869,
#     991,
#     297,
#     937,
#     9,
#     521,
#     1017,
#     631,
#     283,
#     677,
#     253,
#     858,
#     875,
#     855,
#     68,
#     79,
#     633,
#     685,
#     846,
#     634,
#     681,
#     682,
#     637,
#     680,
#     267,
#     688,
#     686,
#     687,
#     596,
#     632,
#     809,
#     689,
#     683,
#     640,
#     657,
#     566,
#     810,
#     636,
#     635,
#     597,
#     589,
#     555,
#     553,
#     684,
#     678,
#     590,
#     562,
#     679,
#     643,
#     159,
#     595,
#     882,
#     895,
#     268,
#     641,
#     561,
#     557,
#     126,
#     556,
#     559,
#     563,
#     638,
#     593,
#     591,
#     594,
#     639,
#     585,
#     560,
#     645,
#     124,
#     114,
#     117,
#     171,
#     447,
#     116,
#     127,
#     273,
#     592,
#     160,
#     156,
#     588,
#     848,
#     464,
#     468,
#     467,
#     451,
#     458,
#     461,
#     586,
#     463,
#     455,
#     462,
#     453,
#     457,
#     587,
#     448,
#     466,
#     444,
#     445,
#     164,
#     119,
#     449,
#     125,
#     642,
#     465,
#     456,
#     452,
#     459,
#     446,
#     583,
#     554,
#     460,
#     161,
#     450,
#     454,
#     130,
#     133,
#     123,
#     131,
#     155,
#     177,
#     154,
#     162,
#     690,
#     143,
#     146,
#     122,
#     113,
#     118,
#     153,
#     135,
#     149,
#     0,
#     175,
#     173,
#     599,
#     141,
#     136,
#     128,
#     644,
#     691,
#     145,
#     151,
#     147,
#     137,
#     152,
#     157,
#     167,
#     150,
#     120,
#     129,
#     121,
#     115,
#     142,
#     138,
#     170,
#     163,
#     134,
#     176,
#     158,
#     166,
#     148,
#     144,
#     660,
#     169,
#     584,
#     132,
#     165,
#     598,
#     568,
#     565,
#     ...],
#    'subarrays': [0, 1, 2, 3, 4, 5, 6, 7]},
#   'noise_injection': {'cyl0.1': {'board': '',
#     'enable': 1,
#     'offset': 0,
#     'high_time': 32768,
#     'period': 65536},
#    '26m': {'board': [7, 0],
#     'enable': 1,
#     'offset': 0,
#     'high_time': 1941504,
#     'period': 23298048,
#     'output': 'bp_sma'}},
#   'adc_delay_params': {'source': 'default',
#    'compute_delays': 1,
#    'save_delays': True,
#    'check_sync_delays': 0,
#    'check_adc_delays': 10,
#    'verbose': 1,
#    'retry': 5},
#   'channelizer_params': {'adc_mode': 'data',
#    'adcdaq_mode': 'data',
#    'data_source': 'adc',
#    'function': '4bit_real_ramp',
#    'fft_bypass': False,
#    'fft_shift': 1367,
#    'scaler_bypass': False,
#    'offset_binary_encoding': True},
#   'raw_data_capture': {'capture_source': 'adc',
#    'baseline_capture_rate': 1,
#    'tmux_factor': 4},
#   'reset_stats': True,
#   'load_initial_gains': True,
#   'gain_hdf5': {'output_dir': '/data/digital_gains',
#    'output_suffix': 'digitalgain',
#    'search': True,
#    'max_num': 1,
#    'max_file_size': 1000000000},
#   'compute_gains': {'enable': False,
#    'save_gains': True,
#    'targets': [['*']],
#    'capture_rate': 15,
#    'number_of_fft_averages': 100,
#    'number_of_gain_update_iterations': 20,
#    'initial_gains': []}},
#  'comet_broker': {'enabled': True, 'host': 'recv1', 'port': 12050},
#  'data_folder': '/data/fpga_master',
#  'n_input': 256,
#  'current_folder': '%(data_folder)s/current',
#  'comment': 'CHIME data acquisition, Crates0-7, shuffle512 mode',
#  'gps': {'servers': {'gpss': {'hostname': 'localhost',
#     'port': 54325,
#     'units': {'gps_west': {'hostname': '10.0.0.10', 'timeout': 5},
#      'gps_east': {'hostname': '10.0.0.11', 'timeout': 5}},
#     'comet_broker': {'enabled': True, 'host': 'recv1', 'port': 12050}}}},
#  'corr_sn': 'FCC',
#  'hostname': 'localhost',
#  'debug': {'allow_empty_fpga_array': True},
#  'raw_acq': {'logging': {'dict_config': {'formatters': {'std': {'format': '%(asctime)s %(levelname)s %(name)s.%(funcName)s() %(filename)s:%(lineno)d>> %(message)s',
#       'datefmt': '%b %d %H:%M:%S'},
#      'short': {'format': '%(asctime)s %(levelname)s %(name)s: %(message)s',
#       'datefmt': '%H:%M:%S'}},
#     'handlers': {'stderr': {'class': 'logging.StreamHandler',
#       'formatter': 'short',
#       'level': 'DEBUG'},
#      'stderr_info': {'class': 'logging.StreamHandler',
#       'formatter': 'short',
#       'level': 'DEBUG'},
#      'syslog': {'class': 'logging.handlers.SysLogHandler',
#       'formatter': 'std',
#       'level': 'DEBUG'},
#      'logfile': {'class': 'logging.FileHandler',
#       'formatter': 'std',
#       'filename': '%(run_folder)s/fpga_master.log'},
#      'pychfpga_logfile': {'class': 'logging.handlers.RotatingFileHandler',
#       'formatter': 'std',
#       'level': 'DEBUG',
#       'filename': '%(run_folder)s/pychfpga.log',
#       'maxBytes': 10000000,
#       'backupCount': 100}},
#     'loggers': {'pychfpga.ps': {'propagate': False,
#       'handlers': ['logfile', 'stderr', 'syslog']}}}},
#   'use_fixed_port_numbers': True,
#   'servers': {'raw_acq0': {'hostname': 'localhost',
#     'port': 54322,
#     'receiver_ports': [{'port': 'myport',
#       'sources': [{'crate': '*', 'slot': '*'}]}]}},
#   'common_config': {'hdf5_capture_refresh_time': 30,
#    'hdf5_capture_duration': 0,
#    'hdf5_capture_folder': '/data/raw_acq/%(hdf5_start_time)s_%(corr_name)s_rawadc',
#    'hdf5_capture_filename': '%(file_number)06d.h5',
#    'hdf5_capture_elements_per_file': 131072,
#    'metrics_refresh_time': 30,
#    'adc_rms_refresh_count': 60,
#    'input_number_map': [12, 13, 14, 15, 8, 9, 10, 11, 4, 5, 6, 7, 0, 1, 2, 3],
#    'jump_thresholds': [24, 48, 96],
#    'comet_broker': {'enabled': True, 'host': 'recv1', 'port': 12050}}},
#  'n_freq': 1024,
#  'input_sn': '%(corr_sn)s%(crate)02d%(slot_zero_based)02d%(input)02d',
#  'port': 54321,
#  'run_name': '%(isotime)s_%(corr_name)s',
#  'input_number_map': [12, 13, 14, 15, 8, 9, 10, 11, 4, 5, 6, 7, 0, 1, 2, 3],
#  'logging': {'base_package_name': 'pychfpga',
#   'script_name': 'pychfpga.fpga_master',
#   'dict_config': {'formatters': {'std': {'format': '%(asctime)s %(levelname)s %(name)s.%(funcName)s() %(filename)s:%(lineno)d>> %(message)s',
#      'datefmt': '%b %d %H:%M:%S'},
#     'short': {'format': '%(asctime)s %(levelname)s %(name)s: %(message)s',
#      'datefmt': '%H:%M:%S'}},
#    'handlers': {'stderr': {'class': 'logging.StreamHandler',
#      'formatter': 'short',
#      'level': 'DEBUG'},
#     'stderr_info': {'class': 'logging.StreamHandler',
#      'formatter': 'short',
#      'level': 'DEBUG'},
#     'syslog': {'class': 'logging.handlers.SysLogHandler',
#      'formatter': 'std',
#      'level': 'DEBUG'},
#     'logfile': {'class': 'logging.handlers.RotatingFileHandler',
#      'formatter': 'std',
#      'level': 'DEBUG',
#      'filename': '%(run_folder)s/fpga_master.log',
#      'maxBytes': 10000000,
#      'backupCount': 100},
#     'pychfpga_logfile': {'class': 'logging.handlers.RotatingFileHandler',
#      'formatter': 'std',
#      'level': 'DEBUG',
#      'filename': '%(run_folder)s/pychfpga.log',
#      'maxBytes': 10000000,
#      'backupCount': 100}},
#    'loggers': {'pychfpga': {'level': 'INFO',
#      'handlers': ['logfile', 'stderr', 'syslog']},
#     'pychfpga.fpga_master': {'level': 'INFO',
#      'handlers': ['logfile', 'stderr', 'syslog'],
#      'propagate': False},
#     'pychfpga.raw_acq': {'level': 'INFO',
#      'handlers': ['logfile', 'stderr', 'syslog'],
#      'propagate': False},
#     'pychfpga.pychfpga': {'level': 'INFO',
#      'handlers': ['pychfpga_logfile', 'stderr', 'syslog'],
#      'propagate': False},
#     'pychfpga.pychfpga.fpga_array': {'level': 'DEBUG',
#      'handlers': ['pychfpga_logfile', 'stderr', 'syslog'],
#      'propagate': False},
#     'pychfpga.ps': {'level': 'INFO',
#      'handlers': ['logfile', 'stderr', 'syslog'],
#      'propagate': True},
#     'pychfpga.kotekan': {'level': 'DEBUG',
#      'handlers': ['logfile', 'stderr', 'syslog'],
#      'propagate': True},
#     'tornado.general': {'level': 'DEBUG',
#      'handlers': ['logfile', 'stderr', 'syslog']}}},
#   'log_levels': None},
#  'corr_name': 'chime',
#  'run_folder': '%(data_folder)s/%(run_name)s',
#  'type': 'config_pychfpga.fpga_master'}
